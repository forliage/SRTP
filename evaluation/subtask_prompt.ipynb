# %% [markdown]
# ### 1. 生产力工具类应用
# 这些工具用于日常办公、任务管理、文件处理等，任务类型丰富且易于模拟常见的用户操作。
# - **Microsoft To Do**：任务管理软件。任务场景可能包括创建新任务、为任务添加到期日期、设置任务优先级、标记任务为已完成等。
# - **Microsoft OneNote**：笔记管理软件。任务包括创建新笔记、为笔记添加标签、嵌入图片或表格、同步笔记等。
# - **Microsoft Outlook**：邮件客户端。任务可以涉及收发邮件、设置自动回复、管理日历活动、创建新联系人等。
# - **Microsoft Word/Excel/PowerPoint**：Office工具。任务包括创建和编辑文档、应用格式、插入图表、使用公式、共享和保存文件等。
# - **Trello**：任务和项目管理工具。任务可能包括创建新看板、添加任务卡片、分配任务给团队成员、设置任务截止日期等。
#
# ### 2. 系统管理类应用
# 这些工具可用于管理系统的设置、文件、设备等，任务可以包括更改配置或执行系统操作。
# - **文件资源管理器（File Explorer）**：文件浏览与管理。任务包括新建文件夹、重命名文件、移动文件、搜索文件、压缩和解压缩文件等。
# - **Windows 设置（Settings）**：系统设置管理。任务包括修改显示设置、连接蓝牙设备、添加新打印机、更改语言和时区等。
# - **任务管理器（Task Manager）**：系统性能监控工具。任务包括查看和结束进程、检查CPU和内存使用情况、查看启动项等。
# - **控制面板（Control Panel）**：旧版设置界面。任务可能包括管理设备和打印机、设置电源选项、修改用户账户控制等。
#
# ### 3. 创意与设计类应用
# 这些工具为用户提供了创作与编辑能力，任务可以涵盖文件的创建、编辑和导出等操作。
# - **Adobe Photoshop/Illustrator**：图像和矢量设计软件。任务可以是打开文件、应用滤镜、调整图像大小、添加图层、保存和导出文件。
# - **Adobe Premiere Pro**：视频编辑软件。任务可能包括导入媒体、剪辑视频、添加过渡效果、导出项目。
# - **Paint 3D**：Windows自带的3D设计软件。任务包括创建新3D模型、添加纹理、调整灯光、保存为3D文件。
# - **GIMP**：开源的图像编辑软件。任务可以包括图片裁剪、图像处理、应用滤镜、保存和导出图片。
#
# ### 4. 通讯与社交类应用
# 这些工具可以涉及文本交流、音视频通话、共享文件等，任务的复杂性可以从简单到高级。
# - **Microsoft Teams**：企业通讯与协作工具。任务包括加入会议、发送聊天信息、创建新团队、共享屏幕等。
# - **Slack**：团队通讯平台。任务可以是发送信息、创建频道、共享文件、设置提醒、添加集成应用。
# - **Zoom**：视频会议工具。任务包括安排会议、加入会议、分享屏幕、录制会议、使用虚拟背景等。
# - **WhatsApp Desktop**：聊天与通话工具。任务可能是发送信息、进行语音通话、共享文件、搜索聊天记录。
#
# ### 5. 多媒体播放与编辑类应用
# 这些应用可以用来播放、管理或编辑多媒体内容。
# - **VLC Media Player**：多功能媒体播放器。任务可以是打开并播放视频、调整播放速度、创建播放列表、截图、转换视频格式等。
# - **Spotify**：音乐流媒体服务。任务包括搜索并播放音乐、创建播放列表、下载音乐、调整音量等。
# - **Photos**：Windows自带的照片查看和编辑软件。任务可能包括浏览图片、创建相册、编辑照片、应用滤镜、导出照片。
#
# ### 6. 安全与优化类应用
# 这些应用程序涉及系统安全和性能优化，任务可以涵盖设置、防护、扫描等。
# - **Windows Defender**：内置的安全防护软件。任务包括扫描系统、启用或禁用防火墙、设置病毒扫描时间等。
# - **CCleaner**：系统清理工具。任务可能包括扫描并清理垃圾文件、清理注册表、卸载程序、管理启动项。
# - **Malwarebytes**：恶意软件清理工具。任务可以是运行系统扫描、查看和清理检测到的威胁、更新病毒库等。
#
# ### 7. 云存储与同步类应用
# 这类应用可以与文件管理、备份、同步等任务相关联。
# - **OneDrive**：Microsoft的云存储服务。任务可能包括上传文件、同步文件夹、查看文件版本历史、共享文件、设置文件访问权限等。
# - **Google Drive**：任务可以是上传文件、创建共享链接、设置文件访问权限、查看文档协作状态。
#
# ### 8. 浏览器与网络类应用
# 浏览器作为常用的应用程序，能涉及到许多网页操作任务。
# - **Microsoft Edge/Google Chrome**：任务可能包括打开网页、添加书签、安装扩展、设置主页、清除缓存等。
# - **Mozilla Firefox**：类似任务，包括配置插件、管理书签、设置隐私选项、启用浏览器同步。

# %% [markdown]
# ### System Prompt
# You are tasked with generating a series of task instructions for a digital agent to operate within the [application_name] software on [OS]. The goal is to define specific actions that the agent should perform to accomplish user tasks within the application. Each task instruction should describe the task clearly and include detailed information about its input and output resources.
#
# ### Application context
# - Application name: [application_name]
# - Operating System: [OS]
# - Application purpose: [brief description of the app’s functionality]
# - Common user actions in the application: [list of common actions such as "add task", "delete task", "set reminder", etc.]
#
# ### Inputs and Outputs
# - Inputs: These represent the resources required for the task to be executed. Inputs can include:
#     - State information: Application state (e.g., a specific screen must be visible).
#     - Files: Specific files needed for the task.
#     - Clipboard content: The information currently in the clipboard.
#     - Other system resources: Network status, user preferences, etc.
#
# A task can only be executed if its input resources are satisfied.
#
# - Outputs: These are the resources produced as a result of the task execution, which may be used by other tasks. Outputs can include:
#     - State changes: The application's state after the task has been completed.
#     - Files: New or modified files.
#     - Clipboard changes: Updated clipboard content.
#     - Other system updates: New tasks created, deleted items, or updated configurations.
#
# ### Please generate task instructions with the following format
# ```json
# {
#   "id": "[unique_id]",
#   "instruction": "[describe the task the agent should perform]",
#   "related_app": "[application_name]",
#   "parameter": { "[dynamic parameters if needed]" },
#   "OS": "[OS]",
#   "input": ["[input resources required for the task to run, such as files, clipboard, specific states, or 'null' if none]"],
#   "output": ["[output resources produced by the task, such as a new state, files, clipboard, or 'null' if none]"]
# }
# ```
#
# ### GUI and API Knowledge
#
#
# ### Example tasks
# 1. Add a new task using clipboard content:
#     - Input: ["text_in_clipboard"] (the content from the clipboard is required)
#     - Output: ["task_created"] (a new task is added to the task list)
# 2. Set a reminder for the first task:
#     - Input: ["first_task_selected"] (the first task must be selected in the list)
#     - Output: ["reminder_set"] (the task will have a reminder set)
# 3. Delete a task:
#     - Input: ["task_idx_selected"] (a task must be selected based on its index)
#     - Output: ["task_deleted"] (the task is removed from the task list)
# 4. Change the due date of the selected task to 'tomorrow':
#     - Input: ["task_idx_selected"] (a task is selected from the list)
#     - Output: ["due_date_updated"] (the due date of the task is changed to tomorrow)

# %% [markdown]
# ### 系统提示
# 您的任务是为Digital Agent生成一系列任务指令。每个任务指令应清晰描述Agent的行为，并包括有关其输入和输出资源的详细信息。
#
# ### 应用程序上下文
# - 应用程序名称: [application_name]
# - 操作系统: [OS]
# - 应用程序目的: [简要描述应用程序的功能]
# - 应用程序中的常见用户操作: [列出常见操作，如“添加任务”、“删除任务”、“设置提醒”等]
#
# ### 输入和输出
# - 输入: 这些代表执行任务所需的资源。输入可以包括:
#     - 状态信息: 应用程序状态（例如，必须显示特定屏幕）。
#     - 文件: 任务所需的特定文件。
#     - 剪贴板内容: 当前剪贴板中的信息。
#     - 其他系统资源: 网络状态、用户偏好等。
#
# 只有在满足其输入资源的情况下，任务才能执行。
#
# - 输出: 这些是任务执行后产生的资源，可能会被其他任务使用。输出可以包括:
#     - 状态变化: 任务完成后应用程序的状态。
#     - 文件: 新文件或修改后的文件。
#     - 剪贴板变化: 更新后的剪贴板内容。
#     - 其他系统更新: 新创建的任务、删除的项目或更新的配置。
#
# ### 请生成以下格式的任务指令
# ```json
# {
#   "id": "[unique_id]",
#   "instruction": "[描述代理应执行的任务]",
#   "related_app": "[application_name]",
#   "parameter": { "[如有需要的动态参数]" },
#   "OS": "[OS]",
#   "input": ["[任务运行所需的输入资源，如文件、剪贴板、特定状态，或'null'如果没有]"],
#   "output": ["[任务产生的输出资源，如新状态、文件、剪贴板，或'null'如果没有]"]
# }
# ```
#
# ### GUI 和 API 知识
#
#
# ### 示例任务
# 1. 使用剪贴板内容添加新任务:
#     - 输入: ["text_in_clipboard"] (需要剪贴板中的内容)
#     - 输出: ["task_created"] (任务列表中添加了一个新任务)
# 2. 为第一个任务设置提醒:
#     - 输入: ["first_task_selected"] (必须在列表中选择第一个任务)
#     - 输出: ["reminder_set"] (任务将设置提醒)
# 3. 删除任务:
#     - 输入: ["task_idx_selected"] (必须根据索引选择一个任务)
#     - 输出: ["task_deleted"] (任务从任务列表中删除)
# 4. 将选定任务的截止日期更改为“明天”:
#     - 输入: ["task_idx_selected"] (从列表中选择一个任务)
#     - 输出: ["due_date_updated"] (任务的截止日期更改为明天)

# %% [markdown]
# # Subtask Generation Pipeline (AN IMPORTANT CONTRIBUTIOM!!!)
# First, choose an application in application list. Then you should provide corresponding Document and Example (2~4).
# For example:
# - Application: Word
# - Document: url content...
# - Example:
#     - 1. Open 'pet introduction.docx' and select all content.
#     - 2. ...
# - Explore in environment util it find a nice instruction.
#     - Goal: Make LLM know how the environment is, including key parameters. e.g. "Dark Gray"
#     - Walk on specific application.
#     - Decide your next action:
#         1. click 'menu' button
#         2. click ...
#         3. summary a task instruction according to previous history.
# - Generate task's trajectory and evaluation.
# - Save task instruction/trajectory/evaluation if Cross Verification is passed in 3 iteration.
# - A subtask knowledge base, when agent explore environment, it could check previous subtask (input and output), benefit to Compostion!
#
# ## Subtask Instruction Generation
# ### Input
# - Environment
# - Graphical User Interface (GUI)
# - Document (if applicable)
# - Example (Manual design)
# ### Output
# - Subtask
#
# ## Subtask Trajectory and Evaluation Generation (Cross Verification)
# ###

# %%
from envs.desktop_env import DesktopEnv
env = DesktopEnv(path_to_vm=r"D:\Virtual_Machines\Windows 11 x64\Windows 11 x64.vmx", action_space="pyautogui", snapshot_name="init_state", headless=True)
