# %%
import os
import json

DAG_path = 'D:/data/task_DAG'

cnt = 0
for file in os.listdir(DAG_path):
    if file.endswith('.json') and file.split('.')[0].isdigit():
        with open(os.path.join(DAG_path, file), 'r', encoding='utf-8') as f:
            response = json.load(f)
            print(response['task_instruction'])
# Out:
# Open 'C:\Users\user\Desktop\office\The Evolution of Urbanization Rate.xlsx', select all data, and copy it. Then, paste the text from the clipboard, translate it into 'Chinese', and copy the result. Finally, open 'C:\Users\user\Desktop\office\pet introduction.docx', paste the translated text from the clipboard, and save it.
# Navigate to the 'C:\Users\user\Desktop\' directory and create a new folder named 'music'. Then, navigate to 'C:\Users\user\Desktop\image\' and copy 'dog.jpg'. Next, navigate to 'C:\Users\user\Desktop\pdf\' and paste the file from the clipboard. Finally, navigate to the 'C:\Users\user\Desktop\image' directory and compress all files into 'C:\Users\user\Desktop\image.zip'.
# ...
